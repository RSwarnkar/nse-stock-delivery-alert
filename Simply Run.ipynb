# %%
# Imports
import requests
import pandas
import os
import datetime
import numpy as np

# %%
# GLOBAL VARS: 

NSE_URL1 = 'https://www1.nseindia.com/products/content/equities/equities/eq_security.htm'

HEADER_REQ1 = {
"Host" : "www1.nseindia.com",
"Connection" : "keep-alive",
"sec-ch-ua":   "\" Not A;Brand\";v=\"99\", \"Chromium\";v=\"90\", \"Google Chrome\";v=\"90\"",
"sec-ch-ua-mobile": "?0",
"Upgrade-Insecure-Requests" : "1",
"User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36",
"Accept" : "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
"Sec-Fetch-Site" : "none",
"Sec-Fetch-Mode" : "navigate",
"Sec-Fetch-User" : "?1",
"Sec-Fetch-Dest" : "document",
"Accept-Encoding" : "gzip, deflate, br",
"Accept-Language" : "en-US,en;q=0.9"
}

DEBUG = True 
INCLUDE_NORMAL_ACTIVITY = True

# %%
def iqr_Anomaly_Upper(datalist,sample):
    if (datalist is None):
        return -1
    # convert to Numpy array. Easy to apply qunatile funtion 
    datalist = np.array(datalist)
    
    Q3, Q1 = np.percentile(datalist, [75 ,25])
    IQR = Q3 - Q1
    
    IQR_ANOMALY_UPPER_THRESHOLD = Q3 + 1.5 * IQR

    if(sample>=IQR_ANOMALY_UPPER_THRESHOLD):
        return 1  # Sample shows high volume activity 
    else:
        return 0  # Sample is normal volume activity 

# Format of the result row: 
# Stockname, Trading Verdit, Delivery Verdict
# ICICIBANK,ABNOMALLY HIGH TRADING,ABNOMALLY HIGH DELIVERY
# DMART,NORMAL TRADING,NOMAL DELIVERY
# DMART,HIGH TRADING,HIGH DELIVERY
# Thresholds = {NORMAL, HIGH, ABNOMALLY HIGH}
def iqrAnomalyCheck(stockname,date,df):

    if not isinstance(df, pandas.DataFrame):
        return str(stockname+","+date+",INVALID DATA,INVALID DATA,INVALID DATA\n")
    if (df is None):
        return str(stockname+","+date+",NULL DATA,NULL DATA,NULL DATA\n")
    if (len(df.index)<7): 
        return str(stockname+","+date+",TOO LESS DATA,TOO LESS DATA,TOO LESS DATA\n")
    #Algorithm for checking {NORMAL, HIGH, ABNOMALLY HIGH}
    
    Trade_Volume_Latest_Sample          = df["Total Traded Quantity"].to_numpy()[-1]
    Trade_Delivery_Latest_Sample        = df["DeliverableQty"].to_numpy()[-1]
    Pct_Delivery_To_Trade_Latest_Sample = df["% Dly Qt toTraded Qty"].to_numpy()[-1]
    
    Trade_Volume   = df["Total Traded Quantity"].to_numpy()[:-1]
    Trade_Delivery = df["DeliverableQty"].to_numpy()[:-1]
    Trade_Pct      = df["% Dly Qt toTraded Qty"].to_numpy()[:-1]
    
    
    Q3_TV, Q1_TV = np.percentile(Trade_Volume, [75 ,25])
    TV_IQR_ANOMALY_UPPER_THRESHOLD = Q3_TV + 1.5 * (Q3_TV - Q1_TV) # UPPER HARD THRESHOLD for Trade Volume
    TV_N95_UPPER_THRESHOLD =  np.percentile(Trade_Volume, 95) # UPPER SOFT THRESHOLD for Trade Volume
    
    
    Q3_TD, Q1_TD = np.percentile(Trade_Delivery, [75 ,25])
    TD_IQR_ANOMALY_UPPER_THRESHOLD = Q3_TD + 1.5 * (Q3_TD - Q1_TD) # UPPER HARD THRESHOLD for Trade Volume
    TD_N95_UPPER_THRESHOLD =  np.percentile(Trade_Delivery, 95) # UPPER SOFT THRESHOLD for Trade Volume
    
    #Q3_PCT, Q1_PCT = np.percentile(Trade_Pct, [75 ,25])
    #PCT_IQR_ANOMALY_UPPER_THRESHOLD = Q3_PCT + 1.5 * (Q3_PCT - Q1_PCT) # UPPER HARD THRESHOLD for Delivery PCT
    #PCT_N95_UPPER_THRESHOLD =  np.percentile(Trade_Pct, 95) # UPPER SOFT THRESHOLD for Delivery PCT
    
    
    # Check Thresholds for Trading: 
    Trade_Volume_Outcome = "NOMAL TRADING"
    Trade_Delivery_Outcome = "NOMAL DELIVERY"
    Trade_PCT_Outcome = "NORMAL DELIVERY PERCENTAGE"
    
    if (Trade_Volume_Latest_Sample>=TV_IQR_ANOMALY_UPPER_THRESHOLD): 
        Trade_Volume_Outcome = "ABNOMALLY HIGH TRADING"
    elif (Trade_Volume_Latest_Sample>=TD_N95_UPPER_THRESHOLD):
        Trade_Volume_Outcome = "HIGH TRADING"
    else:
        Trade_Volume_Outcome = "NORMAL TRADING"
        
    # Check Thresholds for Delivery: 
    if (Trade_Delivery_Latest_Sample>=TD_IQR_ANOMALY_UPPER_THRESHOLD): 
        Trade_Delivery_Outcome = "ABNOMALLY HIGH DELIVERY"
    elif (Trade_Delivery_Latest_Sample>=TD_N95_UPPER_THRESHOLD):
        Trade_Delivery_Outcome = "HIGH DELIVERY"
    else:
        Trade_Delivery_Outcome = "NORMAL DELIVERY"
        
    # Check Thresholds for Percentage Delivery: 
    if (Pct_Delivery_To_Trade_Latest_Sample>=90):   # If >90% then good
        Trade_PCT_Outcome = "ABNOMALLY HIGH DELIVERY PERCENTAGE"
    elif (Pct_Delivery_To_Trade_Latest_Sample>=70):
        Trade_PCT_Outcome = "HIGH DELIVERY PERCENTAGE"
    else:
        Trade_PCT_Outcome = "NORMAL DELIVERY PERCENTAGE"    

    return str(stockname+","+date+","+Trade_Volume_Outcome+","+Trade_Delivery_Outcome+","+Trade_PCT_Outcome+"\n")

# %%
def fetchDataFromNSE(_symbol_list,_lastndays=21): 
    
    
    date_past = str(datetime.date.today() - pandas.offsets.DateOffset(days=_lastndays)).split(" ")[0]
    date_today  = str(datetime.date.today() - pandas.offsets.DateOffset(days=0)).split(" ")[0]
    
    date_past_obj = datetime.datetime.strptime(date_past, '%Y-%m-%d')
    date_today_obj = datetime.datetime.strptime(date_today, '%Y-%m-%d')
    
    
    date_past = date_past_obj.strftime('%d-%m-%Y')
    date_today = date_today_obj.strftime('%d-%m-%Y')

    print("date from ", date_past, type(date_past))
    print("date today ",date_today, type(date_today))
    
    
    #_symbol = "DMART"
    _segmentLink = "3"
    _symbolCount = "1"
    _series = "EQ"
    _dateRange = "+"
    _fromDate = date_past
    _toDate = date_today
    _dataType = "PRICEVOLUMEDELIVERABLE"
    
 
    
    # For debugging
    #print(f"===Start of Params===")
    ##print(f"got symbol:{_symbol}")
    #print(f"got segmentLink:{_segmentLink}")
    #print(f"got symbolCount:{_symbolCount}")
    #print(f"got series:{_series}")
    #print(f"got dateRange:{_dateRange}")
    #print(f"got fromDate:{_fromDate}")
    #print(f"got toDate:{_toDate}")
    #print(f"got dataType:{_dataType}")
    #print(f"===End of Params===")
    
       
 
    sess = requests.Session()
    rs = sess.get(NSE_URL1, headers=HEADER_REQ1)
    
    arr_cookies = [{'name': c.name, 'value': c.value, 'domain': c.domain, 'path': c.path, 'expires': c.expires} for c in sess.cookies]
    parsed_cookies = arr_cookies[0].get('name') + "=" + arr_cookies[0].get('value')
    
    custom_headers = {
            "Host" : "www1.nseindia.com",
            "Connection" : "keep-alive",
            "sec-ch-ua":   "\" Not A;Brand\";v=\"99\", \"Chromium\";v=\"90\", \"Google Chrome\";v=\"90\"",
            "sec-ch-ua-mobile": "?0",
            "Upgrade-Insecure-Requests" : "1",
            "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36",
            "Accept" : "*/*",
            "X-Requested-With" : "XMLHttpRequest",
            "Sec-Fetch-Site" : "same-origin",
            "Sec-Fetch-Mode" : "cors",
            "Sec-Fetch-Dest" : "empty" ,
            "Referer" : "https://www1.nseindia.com/products/content/equities/equities/eq_security.htm",
            "Accept-Encoding" : "gzip, deflate, br",
            "Accept-Language" : "en-US,en;q=0.9",
            "Cookie" : parsed_cookies}
    
 
    final_result_set = ""
    result_row = ""
    
    for _symbol in _symbol_list:
        
        print("-------------------------------------------------")
        print("Checking: Stock: "+_symbol)
 
        rs = requests.get("https://www1.nseindia.com//marketinfo/sym_map/symbolCount.jsp?symbol="+_symbol,headers=custom_headers)
        _symbolCount = str(rs.text).strip()
        
        #print("After calling symbolCount.jsp: symbolCount="+_symbolCount)
        
        custom_query_params = {
           'symbol': _symbol,
           'segmentLink': _segmentLink,
           'symbolCount': _symbolCount,
           'series': _series,
           'dateRange': _dateRange,
           'fromDate': _fromDate,
           'toDate': _toDate,
           'dataType': _dataType}  
 
        rs = requests.get("https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp", params=custom_query_params,headers=custom_headers)
        parsed_tables = pandas.read_html(rs.text)
        
        #valid_data_flag = True
        #if not ("<span><nobr>Data for" in rs.text): 
        #    valid_data_flag = False 
        #with open("C:\\CG505\\CG505_Programming\\nse-volume-api\\temp\\debug.txt", "a+") as f:
        #    f.write(rs.text+"\n\n\n--------------------")
        

        df = pandas.DataFrame(parsed_tables[0])
        
        
        ## Notoriously last column name is having some weird html new lines causing the whole script to fail
        ## https://stackoverflow.com/questions/56479835/rename-only-the-last-column-in-pandas-dataframe-accounting-for-duplicate-header
        #df = df[df.columns.values.tolist()].replace('\\n','')
        #df.columns = [*df.columns[:-1], 'Percent of Delivery Qty to Traded Qty']
        
        #print("Colunm size: "+str(len(df.columns)) ) 
        
        
        time_stamp_file = _symbol +"_"+str(datetime.datetime.now()).replace(" ","-").replace(":","-").replace(".","-") + ".csv"
        
        df.to_csv("temp/"+time_stamp_file)
        ## Debug info:
        print("Columns names in "+_symbol)
        print(list(df.columns.values))
        
        cols_2 = ['Date', 'Total Traded Quantity', 'DeliverableQty','% Dly Qt toTraded Qty']
        
        

        print("#Columns in stock "+_symbol+" : "+str(len(df.columns)))
        
        if (len(df.columns)!=15): # Work on data if and only the data has 15 cols => Proper data
            #print("#Columns in stock "+_symbol+" is not equal to 15")
            result_row = _symbol+",NSE DATA ERROR,NSE DATA ERROR,NSE DATA ERROR,NSE DATA ERROR\n"
            print("*** Result: "+_symbol+" : "+result_row)
        
        else:
            df2 = df[['Date', 'Total Traded Quantity', 'DeliverableQty','% Dly Qt toTraded Qty']].copy()
            Latest_Date = df2["Date"].to_numpy()[-1]
            result_row = iqrAnomalyCheck(_symbol,Latest_Date,df2)
            print("*** Result: "+_symbol+" : "+result_row)
            
 

        final_result_set = final_result_set + result_row
 
    return final_result_set

# %%
def mainFunction():

    fileDir = os.path.dirname(os.path.realpath('__file__'))
    stock_list = []
    with open(os.path.join(fileDir, 'stock-list/stocklist.txt')) as f:
        stock_list = f.read().splitlines()
        
    final_report = fetchDataFromNSE(stock_list, 28)
    
    report_filename = "reports/"+str(datetime.datetime.now()).replace(" ","-").replace(":","-").replace(".","-") + ".csv"
    
    fileDir = os.path.dirname(os.path.realpath('__file__'))
     
    with open(os.path.join(fileDir, report_filename), "w+") as f:
         f.write("STOCK,DATE,TRADING,DELIVERY,DELIVERY PERCENTAGE\n")
         f.write(final_report)
 
    print("\n-------------FINAL REPORT---------------\n")
    print(final_report)
    
    #send_email(os.path.join(fileDir, report_filename))

# %%
mainFunction()
# Out:
# date from  04-03-2022 <class 'str'>
# date today  01-04-2022 <class 'str'>
# -------------------------------------------------
# Checking: Stock: AARTIIND
# Columns names in AARTIIND
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock AARTIIND : 15
# *** Result: AARTIIND : AARTIIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ABBOTINDIA
# Columns names in ABBOTINDIA
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ABBOTINDIA : 15
# *** Result: ABBOTINDIA : ABBOTINDIA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: AFFLE
# Columns names in AFFLE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock AFFLE : 15
# *** Result: AFFLE : AFFLE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ALKYLAMINE
# Columns names in ALKYLAMINE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ALKYLAMINE : 15
# *** Result: ALKYLAMINE : ALKYLAMINE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: AMBER
# Columns names in AMBER
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock AMBER : 15
# *** Result: AMBER : AMBER,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: APOLLOHOSP
# Columns names in APOLLOHOSP
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock APOLLOHOSP : 15
# *** Result: APOLLOHOSP : APOLLOHOSP,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ASHOKLEY
# Columns names in ASHOKLEY
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ASHOKLEY : 15
# *** Result: ASHOKLEY : ASHOKLEY,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ASIANPAINT
# Columns names in ASIANPAINT
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ASIANPAINT : 15
# *** Result: ASIANPAINT : ASIANPAINT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ASTRAL
# Columns names in ASTRAL
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ASTRAL : 15
# *** Result: ASTRAL : ASTRAL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ATUL
# Columns names in ATUL
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ATUL : 15
# *** Result: ATUL : ATUL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BAJAJ-AUTO
# Columns names in BAJAJ-AUTO
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BAJAJ-AUTO : 15
# *** Result: BAJAJ-AUTO : BAJAJ-AUTO,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BAJAJELEC
# Columns names in BAJAJELEC
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BAJAJELEC : 15
# *** Result: BAJAJELEC : BAJAJELEC,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BAJAJFINSV
# Columns names in BAJAJFINSV
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BAJAJFINSV : 15
# *** Result: BAJAJFINSV : BAJAJFINSV,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BAJFINANCE
# Columns names in BAJFINANCE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BAJFINANCE : 15
# *** Result: BAJFINANCE : BAJFINANCE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BATAINDIA
# Columns names in BATAINDIA
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BATAINDIA : 15
# *** Result: BATAINDIA : BATAINDIA,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BERGEPAINT
# Columns names in BERGEPAINT
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BERGEPAINT : 15
# *** Result: BERGEPAINT : BERGEPAINT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BIOCON
# Columns names in BIOCON
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BIOCON : 15
# *** Result: BIOCON : BIOCON,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: BRITANNIA
# Columns names in BRITANNIA
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock BRITANNIA : 15
# *** Result: BRITANNIA : BRITANNIA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ZYDUSLIFE
# Columns names in ZYDUSLIFE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ZYDUSLIFE : 15
# *** Result: ZYDUSLIFE : ZYDUSLIFE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: CAMS
# Columns names in CAMS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock CAMS : 15
# *** Result: CAMS : CAMS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: CDSL
# Columns names in CDSL
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock CDSL : 15
# *** Result: CDSL : CDSL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: CIPLA
# Columns names in CIPLA
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock CIPLA : 15
# *** Result: CIPLA : CIPLA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: DABUR
# Columns names in DABUR
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock DABUR : 15
# *** Result: DABUR : DABUR,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: DEEPAKNTR
# Columns names in DEEPAKNTR
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock DEEPAKNTR : 15
# *** Result: DEEPAKNTR : DEEPAKNTR,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: DIVISLAB
# Columns names in DIVISLAB
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock DIVISLAB : 15
# *** Result: DIVISLAB : DIVISLAB,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: DIXON
# Columns names in DIXON
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock DIXON : 15
# *** Result: DIXON : DIXON,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: DRREDDY
# Columns names in DRREDDY
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock DRREDDY : 15
# *** Result: DRREDDY : DRREDDY,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: EICHERMOT
# Columns names in EICHERMOT
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock EICHERMOT : 15
# *** Result: EICHERMOT : EICHERMOT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ERIS
# Columns names in ERIS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ERIS : 15
# *** Result: ERIS : ERIS,01-Apr-2022,ABNOMALLY HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: EXIDEIND
# Columns names in EXIDEIND
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock EXIDEIND : 15
# *** Result: EXIDEIND : EXIDEIND,01-Apr-2022,HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HAPPSTMNDS
# Columns names in HAPPSTMNDS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HAPPSTMNDS : 15
# *** Result: HAPPSTMNDS : HAPPSTMNDS,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HAVELLS
# Columns names in HAVELLS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HAVELLS : 15
# *** Result: HAVELLS : HAVELLS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HCLTECH
# Columns names in HCLTECH
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HCLTECH : 15
# *** Result: HCLTECH : HCLTECH,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HDFC
# Columns names in HDFC
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HDFC : 15
# *** Result: HDFC : HDFC,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HDFCAMC
# Columns names in HDFCAMC
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HDFCAMC : 15
# *** Result: HDFCAMC : HDFCAMC,01-Apr-2022,ABNOMALLY HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HDFCBANK
# Columns names in HDFCBANK
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HDFCBANK : 15
# *** Result: HDFCBANK : HDFCBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HDFCLIFE
# Columns names in HDFCLIFE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HDFCLIFE : 15
# *** Result: HDFCLIFE : HDFCLIFE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HEROMOTOCO
# Columns names in HEROMOTOCO
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HEROMOTOCO : 15
# *** Result: HEROMOTOCO : HEROMOTOCO,01-Apr-2022,ABNOMALLY HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: HINDUNILVR
# Columns names in HINDUNILVR
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock HINDUNILVR : 15
# *** Result: HINDUNILVR : HINDUNILVR,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ICICIBANK
# Columns names in ICICIBANK
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ICICIBANK : 15
# *** Result: ICICIBANK : ICICIBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ICICIGI
# Columns names in ICICIGI
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ICICIGI : 15
# *** Result: ICICIGI : ICICIGI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ICICIPRULI
# Columns names in ICICIPRULI
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ICICIPRULI : 15
# *** Result: ICICIPRULI : ICICIPRULI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: IDFCFIRSTB
# Columns names in IDFCFIRSTB
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock IDFCFIRSTB : 15
# *** Result: IDFCFIRSTB : IDFCFIRSTB,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: INDIGO
# Columns names in INDIGO
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock INDIGO : 15
# *** Result: INDIGO : INDIGO,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: INFY
# Columns names in INFY
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock INFY : 15
# *** Result: INFY : INFY,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,HIGH DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ITC
# Columns names in ITC
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ITC : 15
# *** Result: ITC : ITC,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: JUBLFOOD
# Columns names in JUBLFOOD
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock JUBLFOOD : 15
# *** Result: JUBLFOOD : JUBLFOOD,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: JYOTHYLAB
# Columns names in JYOTHYLAB
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock JYOTHYLAB : 15
# *** Result: JYOTHYLAB : JYOTHYLAB,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: KOTAKBANK
# Columns names in KOTAKBANK
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock KOTAKBANK : 15
# *** Result: KOTAKBANK : KOTAKBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: LAURUSLABS
# Columns names in LAURUSLABS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock LAURUSLABS : 15
# *** Result: LAURUSLABS : LAURUSLABS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: LT
# Columns names in LT
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock LT : 15
# *** Result: LT : LT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,HIGH DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: LTI
# Columns names in LTI
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock LTI : 15
# *** Result: LTI : LTI,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: LTTS
# Columns names in LTTS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock LTTS : 15
# *** Result: LTTS : LTTS,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: M&M
# Columns names in M&M
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock M&M : 15
# *** Result: M&M : M&M,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: MARICO
# Columns names in MARICO
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock MARICO : 15
# *** Result: MARICO : MARICO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: MARUTI
# Columns names in MARUTI
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock MARUTI : 15
# *** Result: MARUTI : MARUTI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: MINDAIND
# Columns names in MINDAIND
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock MINDAIND : 15
# *** Result: MINDAIND : MINDAIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: MOTHERSUMI
# Columns names in MOTHERSUMI
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock MOTHERSUMI : 15
# *** Result: MOTHERSUMI : MOTHERSUMI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: MUTHOOTFIN
# Columns names in MUTHOOTFIN
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock MUTHOOTFIN : 15
# *** Result: MUTHOOTFIN : MUTHOOTFIN,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: NAUKRI
# Columns names in NAUKRI
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock NAUKRI : 15
# *** Result: NAUKRI : NAUKRI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: NESTLEIND
# Columns names in NESTLEIND
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock NESTLEIND : 15
# *** Result: NESTLEIND : NESTLEIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: PGHH
# Columns names in PGHH
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock PGHH : 15
# *** Result: PGHH : PGHH,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: PIDILITIND
# Columns names in PIDILITIND
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock PIDILITIND : 15
# *** Result: PIDILITIND : PIDILITIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: PIIND
# Columns names in PIIND
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock PIIND : 15
# *** Result: PIIND : PIIND,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: POLYCAB
# Columns names in POLYCAB
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock POLYCAB : 15
# *** Result: POLYCAB : POLYCAB,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: PRINCEPIPE
# Columns names in PRINCEPIPE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock PRINCEPIPE : 15
# *** Result: PRINCEPIPE : PRINCEPIPE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: RELAXO
# Columns names in RELAXO
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock RELAXO : 15
# *** Result: RELAXO : RELAXO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: RELIANCE
# Columns names in RELIANCE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock RELIANCE : 15
# *** Result: RELIANCE : RELIANCE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: SBILIFE
# Columns names in SBILIFE
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock SBILIFE : 15
# *** Result: SBILIFE : SBILIFE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: SBIN
# Columns names in SBIN
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock SBIN : 15
# *** Result: SBIN : SBIN,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: SUNPHARMA
# Columns names in SUNPHARMA
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock SUNPHARMA : 15
# *** Result: SUNPHARMA : SUNPHARMA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TATACHEM
# Columns names in TATACHEM
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TATACHEM : 15
# *** Result: TATACHEM : TATACHEM,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TATACONSUM
# Columns names in TATACONSUM
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TATACONSUM : 15
# *** Result: TATACONSUM : TATACONSUM,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TATAELXSI
# Columns names in TATAELXSI
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TATAELXSI : 15
# *** Result: TATAELXSI : TATAELXSI,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TATAINVEST
# Columns names in TATAINVEST
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TATAINVEST : 15
# *** Result: TATAINVEST : TATAINVEST,01-Apr-2022,ABNOMALLY HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TATAMOTORS
# Columns names in TATAMOTORS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TATAMOTORS : 15
# *** Result: TATAMOTORS : TATAMOTORS,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TATAPOWER
# Columns names in TATAPOWER
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TATAPOWER : 15
# *** Result: TATAPOWER : TATAPOWER,01-Apr-2022,HIGH TRADING,HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TCS
# Columns names in TCS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TCS : 15
# *** Result: TCS : TCS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TECHM
# Columns names in TECHM
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TECHM : 15
# *** Result: TECHM : TECHM,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TITAN
# Columns names in TITAN
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TITAN : 15
# *** Result: TITAN : TITAN,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TRENT
# Columns names in TRENT
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TRENT : 15
# *** Result: TRENT : TRENT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: TVSMOTOR
# Columns names in TVSMOTOR
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock TVSMOTOR : 15
# *** Result: TVSMOTOR : TVSMOTOR,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: ULTRACEMCO
# Columns names in ULTRACEMCO
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock ULTRACEMCO : 15
# *** Result: ULTRACEMCO : ULTRACEMCO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: VBL
# Columns names in VBL
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock VBL : 15
# *** Result: VBL : VBL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: VOLTAS
# Columns names in VOLTAS
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock VOLTAS : 15
# *** Result: VOLTAS : VOLTAS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: WIPRO
# Columns names in WIPRO
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock WIPRO : 15
# *** Result: WIPRO : WIPRO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
# -------------------------------------------------
# Checking: Stock: YESBANK
# Columns names in YESBANK
# ['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price', 'Low Price', 'Last Price', 'Close Price', 'VWAP', 'Total Traded Quantity', 'Turnover', 'No. of Trades', 'DeliverableQty', '% Dly Qt toTraded Qty']
# #Columns in stock YESBANK : 15
# *** Result: YESBANK : YESBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
#
#
# -------------FINAL REPORT---------------
#
# AARTIIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ABBOTINDIA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# AFFLE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ALKYLAMINE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# AMBER,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# APOLLOHOSP,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ASHOKLEY,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ASIANPAINT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ASTRAL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ATUL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BAJAJ-AUTO,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BAJAJELEC,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BAJAJFINSV,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BAJFINANCE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BATAINDIA,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BERGEPAINT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BIOCON,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# BRITANNIA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ZYDUSLIFE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# CAMS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# CDSL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# CIPLA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# DABUR,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# DEEPAKNTR,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# DIVISLAB,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# DIXON,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# DRREDDY,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# EICHERMOT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ERIS,01-Apr-2022,ABNOMALLY HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
# EXIDEIND,01-Apr-2022,HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
# HAPPSTMNDS,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# HAVELLS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# HCLTECH,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# HDFC,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# HDFCAMC,01-Apr-2022,ABNOMALLY HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# HDFCBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# HDFCLIFE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# HEROMOTOCO,01-Apr-2022,ABNOMALLY HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
# HINDUNILVR,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ICICIBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ICICIGI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ICICIPRULI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# IDFCFIRSTB,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# INDIGO,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# INFY,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,HIGH DELIVERY PERCENTAGE
# ITC,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# JUBLFOOD,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# JYOTHYLAB,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# KOTAKBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# LAURUSLABS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# LT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,HIGH DELIVERY PERCENTAGE
# LTI,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# LTTS,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# M&M,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# MARICO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# MARUTI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# MINDAIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# MOTHERSUMI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# MUTHOOTFIN,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# NAUKRI,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# NESTLEIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# PGHH,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# PIDILITIND,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# PIIND,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# POLYCAB,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# PRINCEPIPE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# RELAXO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# RELIANCE,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# SBILIFE,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# SBIN,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# SUNPHARMA,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TATACHEM,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TATACONSUM,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TATAELXSI,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TATAINVEST,01-Apr-2022,ABNOMALLY HIGH TRADING,ABNOMALLY HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
# TATAMOTORS,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TATAPOWER,01-Apr-2022,HIGH TRADING,HIGH DELIVERY,NORMAL DELIVERY PERCENTAGE
# TCS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TECHM,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TITAN,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TRENT,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# TVSMOTOR,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# ULTRACEMCO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# VBL,01-Apr-2022,HIGH TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# VOLTAS,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# WIPRO,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
# YESBANK,01-Apr-2022,NORMAL TRADING,NORMAL DELIVERY,NORMAL DELIVERY PERCENTAGE
